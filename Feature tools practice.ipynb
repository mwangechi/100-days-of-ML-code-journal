# %%
import featuretools as ft
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("Train_UWu5bXk.txt")
test = pd.read_csv("Test_u94Q5KV.txt")

# %%
train.sample()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 474           FDU25        12.35          Low Fat         0.026681    Canned
#
#      Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 474   56.4246            OUT046                       1997       Small
#
#     Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 474               Tier 1  Supermarket Type1           810.9444

# %%
test.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5101           FDJ03        12.35          Regular         0.072381
# 3100           FDJ48        11.30          Low Fat         0.056665
# 1061           FDL15        17.85          Low Fat         0.046635
# 2054           NCA41        16.75          Low Fat         0.032719
# 1533           NCD55        14.00          Low Fat         0.024430
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5101               Dairy   48.4692            OUT035
# 3100        Baking Goods  248.0118            OUT018
# 1061                Meat  154.2682            OUT046
# 2054  Health and Hygiene  194.2162            OUT018
# 1533           Household   42.6454            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5101                       2004       Small               Tier 2
# 3100                       2009      Medium               Tier 3
# 1061                       1997       Small               Tier 1
# 2054                       2009      Medium               Tier 3
# 1533                       2009      Medium               Tier 3
#
#             Outlet_Type
# 5101  Supermarket Type1
# 3100  Supermarket Type2
# 1061  Supermarket Type1
# 2054  Supermarket Type2
# 1533  Supermarket Type2

# %%
#Data Preparation

test_Item_identifier = test['Item_Identifier']
test_Outlet_Identifier = test['Outlet_Identifier']
sales = train['Item_Outlet_Sales']
train.drop(['Item_Outlet_Sales'],axis=1,inplace=True)

# %%
#Combine both train and test data sets

combined = train.append(test,ignore_index=True)

# %%
#Checking missing values
combined.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#Filling in the missing values.
combined['Item_Weight'].fillna(combined['Item_Weight'].mean(),inplace=True)
combined['Outlet_Size'].fillna('missing',inplace=True)

# %%
#Data Preprocessing
combined['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
# Replacing categories

combined['Item_Fat_Content'] = combined['Item_Fat_Content'].replace({'LF':'Low Fat','reg':"Regular","low fat":"Low Fat"})

# %% [markdown]
# ### Feature Engineering using Feature Tools
# <p>  It is necessary to have a unique identifier feature in the dataset.</p>

# %%
# Creating a unique identifier from combination of item and outlet

combined['id'] = combined['Item_Identifier'] + combined['Outlet_Identifier']
combined.drop(['Item_Identifier'], axis=1,inplace=True)

# %%
#Create entity set 

es = ft.EntitySet(id='sales')

# %%
# add a data frame

es.entity_from_dataframe(entity_id='bigmart',dataframe=combined,index='id')
# Out:
# Entityset: sales
#   Entities:
#     bigmart [Rows: 14204, Columns: 11]
#   Relationships:
#     No relationships

# %%
es.normalize_entity(base_entity_id='bigmart',new_entity_id='outlet',index='Outlet_Identifier',
additional_variables = ['Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'])
# Out:
# Entityset: sales
#   Entities:
#     bigmart [Rows: 14204, Columns: 7]
#     outlet [Rows: 10, Columns: 5]
#   Relationships:
#     bigmart.Outlet_Identifier -> outlet.Outlet_Identifier

# %%
print(es)
# Out:
# Entityset: sales
#   Entities:
#     bigmart [Rows: 14204, Columns: 7]
#     outlet [Rows: 10, Columns: 5]
#   Relationships:
#     bigmart.Outlet_Identifier -> outlet.Outlet_Identifier

# %%
#Deep feature synthesis

feature_matrix,feature_names = ft.dfs(entityset=es,target_entity='bigmart',max_depth=2,verbose=1,n_jobs=3)
# Out:
# Built 33 features
# EntitySet scattered to 3 workers in 2 seconds
# Elapsed: 00:01 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks

# %%
feature_matrix.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'outlet.Outlet_Establishment_Year',
#        'outlet.Outlet_Size', 'outlet.Outlet_Location_Type',
#        'outlet.Outlet_Type', 'outlet.SUM(bigmart.Item_Weight)',
#        'outlet.SUM(bigmart.Item_Visibility)', 'outlet.SUM(bigmart.Item_MRP)',
#        'outlet.STD(bigmart.Item_Weight)',
#        'outlet.STD(bigmart.Item_Visibility)', 'outlet.STD(bigmart.Item_MRP)',
#        'outlet.MAX(bigmart.Item_Weight)',
#        'outlet.MAX(bigmart.Item_Visibility)', 'outlet.MAX(bigmart.Item_MRP)',
#        'outlet.SKEW(bigmart.Item_Weight)',
#        'outlet.SKEW(bigmart.Item_Visibility)', 'outlet.SKEW(bigmart.Item_MRP)',
#        'outlet.MIN(bigmart.Item_Weight)',
#        'outlet.MIN(bigmart.Item_Visibility)', 'outlet.MIN(bigmart.Item_MRP)',
#        'outlet.MEAN(bigmart.Item_Weight)',
#        'outlet.MEAN(bigmart.Item_Visibility)', 'outlet.MEAN(bigmart.Item_MRP)',
#        'outlet.COUNT(bigmart)', 'outlet.NUM_UNIQUE(bigmart.Item_Fat_Content)',
#        'outlet.NUM_UNIQUE(bigmart.Item_Type)',
#        'outlet.MODE(bigmart.Item_Fat_Content)',
#        'outlet.MODE(bigmart.Item_Type)'],
#       dtype='object')

# %%
feature_matrix.head()
# Out:
#              Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# id
# DRA12OUT010    11.600000          Low Fat         0.068535  Soft Drinks
# DRA12OUT013    11.600000          Low Fat         0.040912  Soft Drinks
# DRA12OUT017    11.600000          Low Fat         0.041178  Soft Drinks
# DRA12OUT018    11.600000          Low Fat         0.041113  Soft Drinks
# DRA12OUT027    12.792854          Low Fat         0.040748  Soft Drinks
#
#              Item_MRP Outlet_Identifier  outlet.Outlet_Establishment_Year  \
# id
# DRA12OUT010  143.0154            OUT010                              1998
# DRA12OUT013  142.3154            OUT013                              1987
# DRA12OUT017  140.3154            OUT017                              2007
# DRA12OUT018  142.0154            OUT018                              2009
# DRA12OUT027  140.0154            OUT027                              1985
#
#             outlet.Outlet_Size outlet.Outlet_Location_Type outlet.Outlet_Type  \
# id
# DRA12OUT010            missing                      Tier 3      Grocery Store
# DRA12OUT013               High                      Tier 3  Supermarket Type1
# DRA12OUT017            missing                      Tier 2  Supermarket Type1
# DRA12OUT018             Medium                      Tier 3  Supermarket Type2
# DRA12OUT027             Medium                      Tier 3  Supermarket Type3
#
#              ...  outlet.MIN(bigmart.Item_Visibility)  \
# id           ...
# DRA12OUT010  ...                                  0.0
# DRA12OUT013  ...                                  0.0
# DRA12OUT017  ...                                  0.0
# DRA12OUT018  ...                                  0.0
# DRA12OUT027  ...                                  0.0
#
#              outlet.MIN(bigmart.Item_MRP)  outlet.MEAN(bigmart.Item_Weight)  \
# id
# DRA12OUT010                       32.6558                         12.722870
# DRA12OUT013                       31.4900                         12.788139
# DRA12OUT017                       32.0900                         12.782080
# DRA12OUT018                       31.8900                         12.803638
# DRA12OUT027                       31.2900                         12.792854
#
#              outlet.MEAN(bigmart.Item_Visibility)  \
# id
# DRA12OUT010                              0.101939
# DRA12OUT013                              0.060242
# DRA12OUT017                              0.061142
# DRA12OUT018                              0.059976
# DRA12OUT027                              0.060344
#
#              outlet.MEAN(bigmart.Item_MRP)  outlet.COUNT(bigmart)  \
# id
# DRA12OUT010                     141.159742                    925
# DRA12OUT013                     141.128428                   1553
# DRA12OUT017                     140.998931                   1543
# DRA12OUT018                     141.000899                   1546
# DRA12OUT027                     141.012347                   1559
#
#              outlet.NUM_UNIQUE(bigmart.Item_Fat_Content)  \
# id
# DRA12OUT010                                            2
# DRA12OUT013                                            2
# DRA12OUT017                                            2
# DRA12OUT018                                            2
# DRA12OUT027                                            2
#
#              outlet.NUM_UNIQUE(bigmart.Item_Type)  \
# id
# DRA12OUT010                                    16
# DRA12OUT013                                    16
# DRA12OUT017                                    16
# DRA12OUT018                                    16
# DRA12OUT027                                    16
#
#              outlet.MODE(bigmart.Item_Fat_Content)  \
# id
# DRA12OUT010                                Low Fat
# DRA12OUT013                                Low Fat
# DRA12OUT017                                Low Fat
# DRA12OUT018                                Low Fat
# DRA12OUT027                                Low Fat
#
#              outlet.MODE(bigmart.Item_Type)
# id
# DRA12OUT010           Fruits and Vegetables
# DRA12OUT013           Fruits and Vegetables
# DRA12OUT017                     Snack Foods
# DRA12OUT018           Fruits and Vegetables
# DRA12OUT027           Fruits and Vegetables
#
# [5 rows x 33 columns]

# %%
feature_matrix = feature_matrix.reindex(index=combined['id'])
feature_matrix = feature_matrix.reset_index()

# %%
feature_matrix.head()
# Out:
#             id  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0  FDA15OUT049         9.30          Low Fat         0.016047
# 1  DRC01OUT018         5.92          Regular         0.019278
# 2  FDN15OUT049        17.50          Low Fat         0.016760
# 3  FDX07OUT010        19.20          Regular         0.000000
# 4  NCD19OUT013         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    outlet.Outlet_Establishment_Year outlet.Outlet_Size  \
# 0                              1999             Medium
# 1                              2009             Medium
# 2                              1999             Medium
# 3                              1998            missing
# 4                              1987               High
#
#   outlet.Outlet_Location_Type  ... outlet.MIN(bigmart.Item_Visibility)  \
# 0                      Tier 1  ...                                 0.0
# 1                      Tier 3  ...                                 0.0
# 2                      Tier 1  ...                                 0.0
# 3                      Tier 3  ...                                 0.0
# 4                      Tier 3  ...                                 0.0
#
#    outlet.MIN(bigmart.Item_MRP)  outlet.MEAN(bigmart.Item_Weight)  \
# 0                       32.4558                         12.803003
# 1                       31.8900                         12.803638
# 2                       32.4558                         12.803003
# 3                       32.6558                         12.722870
# 4                       31.4900                         12.788139
#
#    outlet.MEAN(bigmart.Item_Visibility)  outlet.MEAN(bigmart.Item_MRP)  \
# 0                              0.059000                     141.163199
# 1                              0.059976                     141.000899
# 2                              0.059000                     141.163199
# 3                              0.101939                     141.159742
# 4                              0.060242                     141.128428
#
#    outlet.COUNT(bigmart)  outlet.NUM_UNIQUE(bigmart.Item_Fat_Content)  \
# 0                   1550                                            2
# 1                   1546                                            2
# 2                   1550                                            2
# 3                    925                                            2
# 4                   1553                                            2
#
#    outlet.NUM_UNIQUE(bigmart.Item_Type)  \
# 0                                    16
# 1                                    16
# 2                                    16
# 3                                    16
# 4                                    16
#
#    outlet.MODE(bigmart.Item_Fat_Content)  outlet.MODE(bigmart.Item_Type)
# 0                                Low Fat           Fruits and Vegetables
# 1                                Low Fat           Fruits and Vegetables
# 2                                Low Fat           Fruits and Vegetables
# 3                                Low Fat           Fruits and Vegetables
# 4                                Low Fat           Fruits and Vegetables
#
# [5 rows x 34 columns]
